# %% [markdown]
# ### Iterating Loops

# %% [markdown]
# ![ex01.png](attachment:14b0e017-b35c-4c9b-b91b-fc7cbc96e0f0.png)

# %% [markdown]
# ![ex02.png](attachment:35d1db50-6155-49be-94d0-1d10f7560aae.png)

# %% [markdown]
# ![ex03.png](attachment:dfc69707-8ddb-4776-b8bb-85c208cd9df6.png)

# %% [markdown]
# ![ex04.png](attachment:482854c6-f7e2-495e-a6b3-92eba45a56ed.png)

# %% [markdown]
# ### Conditional Loops

# %% [markdown]
# ![ex05.png](attachment:76311635-480c-48af-afa6-fb4a809f62c6.png)

# %% [markdown]
# ![ex06.png](attachment:33a3b475-3a5d-4e38-9131-1362f36edb0d.png)

# %% [markdown]
# ![ex07.png](attachment:719e50f0-cc10-4d40-b1c7-26877bf91134.png)
