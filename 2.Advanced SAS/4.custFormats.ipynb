# %% [markdown]
# ### Custom Formats

# %% [markdown]
# In Creating Custom Formats, you learn to create and use custom formats to enhance the way your data is displayed in a table or report.

# %% [markdown]
# ![ex1.png](attachment:b8409c87-6f0d-4a76-b3a4-c67edadebe1b.png)

# %% [markdown]
# ![ex2.png](attachment:60c7732c-5c60-4d31-bf58-230577538b1a.png)
