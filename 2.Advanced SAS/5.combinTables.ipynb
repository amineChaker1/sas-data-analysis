# %% [markdown]
# ### Combining Tables

# %% [markdown]
# In Combining Tables we take a comprehensive look at combining tables by using the DATA step. You learn to concatenate tables, merge tables, and identify matching and nonmatching rows.

# %% [markdown]
# ![ex00.png](attachment:ccc04abd-c53c-498a-b70a-de287918a2ee.png)

# %% [markdown]
# ### Merging Tables

# %% [markdown]
# ![ex1.png](attachment:29e583b1-5bb2-48ae-8f09-ce312c01a620.png)

# %% [markdown]
# ![ex00.png](attachment:79ac3ffd-e44a-427a-a52d-4916c61e3e8b.png)

# %% [markdown]
# ![ex1.png](attachment:3379f995-3b25-4c75-9d97-9633bd7bbb2a.png)
