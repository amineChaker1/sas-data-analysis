# %% [markdown]
# ### Using SQL in Sas

# %% [markdown]
# SQL is typically used in the Prepare data and Analyze and report on data phases of the SAS programming process. SQL provides an alternative paradigm for processing and reporting on tabular data. Most database management systems use SQL as a common language to query, manipulate, and report on tables. Because of its widespread use and unique processing strengths, SQL can be used in SAS programs through a procedure, PROC SQL.

# %% [markdown]
# ![ex1.png](attachment:f5a9a6c3-926a-47ef-a212-2850a1d295d5.png)

# %% [markdown]
# ![ex2.png](attachment:dbe4ca94-1987-4bb7-859f-a6f532321e64.png)

# %% [markdown]
# ![ex3.png](attachment:cf396f5f-d10e-4fd3-aeca-6f369cbb19ac.png)

# %% [markdown]
# ### Joining Tables in Sas

# %% [markdown]
# ![ex4.png](attachment:28f0b70b-4cfd-4795-8cf5-81a7d5f1849a.png)

# %% [markdown]
# ![ex5.png](attachment:7e0fe291-57b0-4575-948e-1fc750326b62.png)
