# %% [markdown]
# ### Getting Started with SAS

# %% [markdown]
# Before you start writing SAS programs you need to know the essentials. Wich are SAS programming tools and the fundamentals of SAS program structure and syntax.

# %% [markdown]
# ![Screenshot_2024-07-16_123018-removebg-preview.png](attachment:ec04121e-99a2-462d-81ef-ae9d955545fe.png)

# %% [markdown]
# THE SYNTAX :

# %% [markdown]
# ![syn1.png](attachment:973e85b9-352a-4335-b4fb-55647b78b484.png)

# %% [markdown]
# ![syn2.png](attachment:e8b993f4-362f-447b-bfba-0068985e4e6c.png)

# %% [markdown]
# ### Accessing Data

# %% [markdown]
# In Accessing Data, you learn to identify the features of a SAS table, access data through libraries, and import data into SAS. (Data can come from a variety of locations and in many formats. Your data might be structured or unstructured. It might be SAS data, a Microsoft Excel file....)

# %% [markdown]
# ![sum1.png](attachment:2dbceaa7-b688-4be3-aad8-75a6a31bed9e.png)

# %% [markdown]
# ![sum2.png](attachment:687b27d1-35fb-4754-8ec5-657972f7fd56.png)

# %% [markdown]
# the diffrence between the import and the libname when it comes to excel files

# %% [markdown]
# ![Screenshot 2024-07-24 105104.png](attachment:f515e3bc-e7fd-498d-907f-89268428d310.png)

# %% [markdown]
# ### Exploring Data

# %% [markdown]
# In Exploring and Validating Data, you learn to use SAS procedures that provide insights about your data. You also learn to subset data so you can focus on particular segments, format data so you can easily understand it, and sort data to identify and resolve duplicate values.

# %% [markdown]
# ![ex1.png](attachment:5d2126c1-8dd6-49c7-8c27-33a71f7289f3.png)

# %% [markdown]
# ![ex1.png](attachment:c193ef12-b59a-4489-b7f8-32e836d9582f.png)

# %% [markdown]
# ![ex2.png](attachment:b698c769-73ef-4cb9-9406-1f3ebcd0695b.png)

# %% [markdown]
# ![ex3.png](attachment:83c13b62-0f32-49a3-b5b1-e3bf29aeb8f8.png)

# %% [markdown]
# ![ex4.png](attachment:e8793ace-72df-40bd-9cc5-b307b6942e1f.png)

# %% [markdown]
# ![ex5.png](attachment:fc3e168a-b8bf-4a48-8fc2-730e6c5f50fd.png)

# %% [markdown]
# ![ex6.png](attachment:b2fdc1d3-f244-464f-ab12-ae76f7d0a93d.png)

# %% [markdown]
# ### Preparing Data
