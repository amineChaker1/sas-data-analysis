# %% [markdown]
# ### Preparing Data

# %% [markdown]
# In Preparing Data you learn how to do some common data manipulations, such as filtering rows and columns, computing new columns, and performing conditional processing.

# %% [markdown]
# ![ex1.png](attachment:501af14f-cb19-44cd-ae2f-a798b292db73.png)

# %% [markdown]
# ![ex2.png](attachment:33521756-e786-4de2-bfaf-ee391aad50ff.png)

# %% [markdown]
# ![ex3.png](attachment:8cf0a446-5ba5-44a0-a291-acdcdf61a576.png)

# %% [markdown]
# ![ex1.png](attachment:6f6931c8-443c-4198-8c38-35f6ff1838f4.png)

# %% [markdown]
# ![ex2.png](attachment:b96fcd12-3720-432d-888c-b48a9726eca9.png)

# %% [markdown]
# ![ex3.png](attachment:671892c2-4788-4f2b-9449-0a197e1cb839.png)

# %% [markdown]
# ![ex4.png](attachment:2e260f6b-eb56-413b-b99b-a2e5aa2399ef.png)
