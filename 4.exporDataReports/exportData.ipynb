# %% [markdown]
# ### Exporting Data

# %% [markdown]
# In Exporting Results you learn to export SAS tables and results to Excel, Microsoft Word, and PDF files.

# %% [markdown]
# ![ex1.png](attachment:4a9dd1d1-f72d-4fcd-a1c7-a5c1512ffb2e.png)

# %% [markdown]
# ![ex2.png](attachment:5bab793f-178c-4230-a9c9-8649d0509999.png)

# %% [markdown]
# ### Exporting Reports

# %% [markdown]
# ![ex2.png](attachment:0a91d7ac-413a-4bb0-a60b-336575a1c4da.png)

# %% [markdown]
# ![ex3.png](attachment:f59b57ce-8651-4462-8d3b-267437ca2027.png)

# %% [markdown]
# ![ex4.png](attachment:6c0ecf19-1f19-44ef-ba5c-9d66bca4ef13.png)

# %% [markdown]
# ![ex5.png](attachment:726ae509-2310-4618-a439-3bb7f2c28d5b.png)
